# %%
import pandas as pd

# Load the uploaded CSV file
file_path = 'C://Users//acer//OneDrive//Desktop//Bnmit//Projects & Assignments//Cloud Computing Protemics//food.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
df.head()
# Out:
#   Category                     Description  Nutrient Data Bank Number  \
# 0     Milk                     Milk, human                   11000000
# 1     Milk                       Milk, NFS                   11100000
# 2     Milk                     Milk, whole                   11111000
# 3     Milk         Milk, low sodium, whole                   11111100
# 4     Milk  Milk, calcium fortified, whole                   11111150
#
#    Data.Alpha Carotene  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                    0                   7                        0
# 1                    0                   4                        0
# 2                    0                   7                        0
# 3                    0                   7                        0
# 4                    0                   7                        0
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Choline  Data.Fiber  ...  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

# Calculate the average carbohydrate content per category
avg_carbs = df.groupby('Category')['Data.Carbohydrate'].mean().sort_values()

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x=avg_carbs, y=avg_carbs.index, palette="viridis", hue=avg_carbs.index, dodge=False, legend=False)

plt.title('Average Carbohydrate Content per Food Category')
plt.xlabel('Average Carbohydrate Content (g)')
plt.ylabel('Food Category')
plt.show()

# %%
# Select relevant columns for the heatmap
nutrient_columns = df.columns[df.columns.str.startswith('Data.')]
correlation_matrix = df[nutrient_columns].corr()

# Create a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap of Nutrients')
plt.show()

# %%
# Select a subset of nutrient columns for the pair plot
selected_columns = ['Data.Carbohydrate', 'Data.Protein', 'Data.Fat', 'Data.Fiber']
selected_data = df[selected_columns]

# Create a pair plot
sns.pairplot(selected_data, kind='scatter', plot_kws={'alpha':0.6})

plt.suptitle('Pair Plot of Selected Nutrients', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Select a subset of nutrient columns for the pair plot
#       2 selected_columns = ['Data.Carbohydrate', 'Data.Protein', 'Data.Fat', 'Data.Fiber']
# ----> 3 selected_data = df[selected_columns]
#       5 # Create a pair plot
#       6 sns.pairplot(selected_data, kind='scatter', plot_kws={'alpha':0.6})
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
# Create a box plot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Data.Vitamins.Vitamin A - RAE', data=df, palette="Set3")

plt.title('Vitamin A Content Across Food Categories')
plt.xlabel('Food Category')
plt.ylabel('Vitamin A - RAE (mcg)')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_12524\3059862563.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Data.Vitamins.Vitamin A - RAE', data=df, palette="Set3")
